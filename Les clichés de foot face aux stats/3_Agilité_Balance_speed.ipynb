# %% [markdown]
# # RELATION ENTRE BALANCE, AGILITE ET RAPIDITE D'UN MEME JOUEUR

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# L'agilité d'un joueur signifie qu'un joueur a la possibilité de changer de direction sans perdre l'équilibre (la balance) ou la vitesse. Est-ce que cette hypothèse pourrait etre validée avec les données des joueurs fournis ? Le but de ce notebook est d'essayer de le faire.

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %% [markdown]
# ### A - Relation entre balance et agilité

# %%
get_corre("balance","agility")
# Out:
# Le coefficient de correlation est =  0.7533523694745826

# %% [markdown]
# Donc ces 2 attributs sont corrélés en croissance

# %% [markdown]
# ### B - Relation entre agilité et rapidité

# %%
get_corre("agility","sprint_speed")
# Out:
# Le coefficient de correlation est =  0.7098007228491375

# %% [markdown]
# Donc ces 2 attributs sont corrélés en croissance aussi

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# Les coefficients de corrélation sont supérieurs à 0.7 dans les deux cas, donc la balance du joueur et son agilité sont corrélées en croissance et de même pour sa vitesse avec l'agilité. Donc on peut valider l'hypothèse logique de départ : L'agilité signifie qu'un joueur a la possibilité de changer de direction sans perdre l'équilibre (la balance) ou la vitesse.

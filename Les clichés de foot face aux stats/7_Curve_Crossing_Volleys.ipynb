# %% [markdown]
# # Relation entre le type de passes efféctué par un joueur avec le ball control

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# Tous les joueurs ne savent pas tirer le ballon en courbe. Donc est-ce que cette capacité unique a des effets sur d'autres caractéristiques du joueur? Avec les données fournis dans la table "playerAttributes", l'attribut "curve" représente la capcité d'un joueur de tirer en courbe, donc on a décidé de voir si cet attribut a un effet sur la valeur des attributs "crossing" et "volleys".

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %% [markdown]
# ### A - Relation entre CURVE et CROSSING

# %%
get_corre("curve", "crossing")
# Out:
# Le coefficient de correlation est =  0.8041802864757432

# %% [markdown]
# Le calcul du coefficient de corrélation a donné 0.8, ce qui veut dire que les deux variables sont fortement corrélées en croissance, c'est à dire plus le joueur a tendance à courber le ballon, plus il réussit à faire des crossing.

# %% [markdown]
# ### B - Relation entre CURVE et VOLLEYS

# %%
get_corre("curve","volleys")
# Out:
# Le coefficient de correlation est =  0.7598157467473928

# %% [markdown]
# On a un coefficient de correlation égal à 0.75 ce qui veut dire que les deux variables sont corrélées en croissance, donc plus le joueur sait tirer en courbe, plus il a tendance à réussir ses volleys.

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# A partir des 2 coefficients obtenus, on peut conclure que la capacité d'un joueur de tirer le ballon en courbe lui donne effectivement des capacités supplémentaires telles que sa capacité à réussir ses crossing et ses volleys.

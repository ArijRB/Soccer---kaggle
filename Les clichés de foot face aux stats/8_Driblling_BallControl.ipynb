# %% [markdown]
# # Relation entre le pourcentage de drible chez un joueur et sa capacité à posséder le ballon

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# En analysant les données du projet, on a remarqué que dans la table "playerAttributes" il y a la valeur de drible ainsi que la valeur du control du ballon pour chaque joueur. On voulait donc voir si il y a une relation entre le fait qu'un joueur fait beaucoup du dribling et son control sur le ballon , et si oui quel est le type de cette relation.

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %%
get_corre("dribbling","ball_control")
# Out:
# Le coefficient de correlation est =  0.9157376568355928

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# Le calcul du coefficient de corrélation entre le pourcentage de dribble et celui de controle de balle a donné 0.91, ce qui veut dire que les deux variable sont fortement corrélées en croissance.
# On peut donc conclure que plus un joueur a tendance à dribbler, plus il pourra controler la balle une fois en sa possession.

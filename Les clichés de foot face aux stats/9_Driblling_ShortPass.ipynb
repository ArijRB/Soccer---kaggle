# %% [markdown]
# # Relation entre le pourcentage de driblle chez un joueur et le nombre de short pass qu'il effectue

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# Quelle est la relation entre le fait qu'un joueur fait du dribbling, et le fait qu'il fait des passes courts ?
# Ce notebook sert à découvrir cette relation

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %%
get_corre("dribbling", "short_passing")
# Out:
# Le coefficient de correlation est =  0.8074985117215265

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# On constate un coefficient de corrélation égale à 0.8, donc on peut dire à partir de celà ainsi qu'à partir de l'observation du nuage de point, que les deux variables short_passing et driblling sont corrélés en croissance et donc on déduit qu'un joueur qui a l'habitude de dribbler, a tendance à faire des passes courtes, ce qui est bien logique.

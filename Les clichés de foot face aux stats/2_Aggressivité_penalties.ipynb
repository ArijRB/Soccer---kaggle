# %% [markdown]
# # RELATION ENTRE AGGRESSIVITE ET PENALTIES D'UN MEME JOUEUR

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# En analysant les données du projet, on a remarqué que dans la table "playerAttributes" il y a la valeur de l'aggressivité et le nombre de penalties pour chaque joueur. On pourrait penser que plus un joueur est aggressif, plus il aura de penalties pendant les matches, donc les 2 attributs sont peut etre corrélés corrélés. En partant de ces données, on voulait donc valider mon hypothèse.

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %%
get_corre("aggression","penalties")
# Out:
# Le coefficient de correlation est =  0.2503794582756807

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# On a obtenu un coefficient de correlation de 0.25 entre les 2 attributs aggressivité et penalties. On ne peut pas donc dire que ces derniers sont corrélés. Contrairement à ce que l'on pourrait penser, etre aggressif ne veut pas forcément dire que le joueur aura plus de penalties que les autres !

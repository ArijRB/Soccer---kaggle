# %% [markdown]
# # Relation entre le type de passes efféctué par un joueur avec le ball control

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# A partir des données des joueurs fournis, on a pensé aux questions suivantes: Est-ce que le type de passes qu'un joueur effectue influence son control sur le ballon pendant le match? Et si oui, quel type de passe l'influence le plus?
# Le but de ne notebook est de répondre à ces 2 questions

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale

# %% [markdown]
# ### A - On étudie d'abord la relation entre les "short passes" effectué par un joueur et le ball control

# %%
get_corre("ball_control","short_passing")
# Out:
# Le coefficient de correlation est =  0.903522346918308

# %% [markdown]
# On remarque à partir du coefficient de corrélation ainsi que le nuage de points que les deux variables sont fortement corrélées en croissance (coeff presque egale à 1). Mais pour pouvoir tirer une conclusion concernant la relation se trouvant entre le control sur le ballon et les courtes passes du joueur, il faut bien évidemment étudier comment varie le control sur le ballon si le joueur a tendance a tirer de longs coups.

# %% [markdown]
# ### B - On va étudier la relation entre les "long passes" effectué par un joueur et le ball control

# %%
get_corre("ball_control","long_passing")
# Out:
# Le coefficient de correlation est =  0.7467790868926035

# %% [markdown]
# On trouve donc un coefficient de corrélation important, mais plus petit que celui calculé plus haut, donc la correlation est plus forte avec les passes courts qu'avec les passes longs

# %% [markdown]
# ## IV - Résultats et Conclusion

# %% [markdown]
# A partir des 2 coefficients obtenus. On peut répondre à notre première de question de départ en disant que les passes effectués par un joueur influence son control sur le ballon.
# Néanmoins, les passes courts (avec un coefficient de 0.9) influence plus le control que les passes longs (avec un coefficient de 0.74), donc les passes courts permettent de plus de controller le ballon; ce qui est plus logique, car avec des passes courtes il est plus faciles de récuperer la balle.

# %% [markdown]
# ## I - Description du Problème

# %% [markdown]
# Dans ce notebook, on veut découvrir la relation entre l'interception d'un joueur sur le terrain, et d'autres attributs divers (marking, standing tackle, sliding tackle)

# %% [markdown]
# ## II - Préparation des données

# %% [markdown]
# La lecture des tables se fait dans le notebook get_corr.ipynb afin de rendre le code plus généralisé. Ce notebook contient aussi la méthode get_corr(attribut1, attribut2) qui permet de calculer le coefficient de corrélation entre n'importe quels 2 attributs de la table playerAttributes

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import math

# %run ./get_corr.ipynb

# %% [markdown]
# ## III - Protocole expérimentale et Conclusions

# %% [markdown]
# ### A - Relation entre Interception et marking

# %%
get_corre("interceptions","marking")
# Out:
# Le coefficient de correlation est =  0.8956066008286522

# %% [markdown]
# ### CONCLUSION POUR A :

# %% [markdown]
# On constate un coefficient de corrélation égal à 0.89, donc on peut déduire qu'il y a une forte relation entre les interceptions d'un joueur sur le terrain ainsi que le poucentage de marking de ce joueur, ce qui est bien cohérent car le principe du marking est qu'un défenseur se met devant un joueur de l'équipe adverse pour le marquer et donc si l'on lui passe la balle, c'est bien évident qu'il l'intercepte.

# %% [markdown]
# ### B - Relation entre Interception et Standing Tackle

# %%
get_corre("interceptions","standing_tackle")
# Out:
# Le coefficient de correlation est =  0.9085485231051377

# %% [markdown]
# ### CONCLUSION POUR B :

# %% [markdown]
# On a un coefficient de corrélation de 0.9, donc on déduit que ces deux variables sont fortement corrélés, ce qui peut s'expliquer par le fait que si un joueur maitrise les interceptions ca va souvent de même avec les tacles, car les deux sont des méthodes défensives, et généralement les défenseurs sont bons dans les deux.

# %% [markdown]
# ### C - Relation entre Interception et Sliding Tackle

# %%
get_corre("interceptions","sliding_tackle")
# Out:
# Le coefficient de correlation est =  0.9012441866071464

# %% [markdown]
# ### CONCLUSION POUR C :

# %% [markdown]
# On constate un coefficient de corrélation de 0.9, ce qui s'explique de la même manière qu'avec les standing tackles.

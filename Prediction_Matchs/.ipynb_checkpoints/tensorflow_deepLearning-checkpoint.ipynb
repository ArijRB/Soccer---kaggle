# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import numpy as np

import tensorflow as tf
import random
tf.logging.set_verbosity(tf.logging.INFO)

# %%
train_data = np.load("./train_data.npy")
train_labels = np.load("./train_labels.npy")
print("TAILLE = "+ str(len(train_data)))
eval_data = np.load("./test_data.npy")
print("TAILLE = "+ str(len(eval_data)))
eval_labels = np.load("./test_labels.npy")
train_data = train_data.astype(dtype= np.float32)
eval_data = eval_data.astype(dtype= np.float32)
# Out:
# TAILLE = 14357
# TAILLE = 6153

# %%
for i in range(len(train_labels)):
    if(train_labels[i] == -1):
        train_labels[i] = 0

for i in range(len(eval_labels)):
    if(eval_labels[i] == -1):
        eval_labels[i] = 0

# %%
def cnn_model_fn(features, labels, mode):
    """Model function for CNN."""
    # Input Layer
    input_layer = tf.reshape(features["x"], [-1, 1, 18, 1])

    # Convolutional Layer #1
    conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=5,
      strides=[1,1],
      kernel_size=[1, 2],
      padding="same",
      activation=tf.nn.relu)
    
    # Convolutional Layer #1
    conv2 = tf.layers.conv2d(
      inputs=conv1,
      filters=5,
      strides=[1,1],
      kernel_size=[1, 2],
      padding="same",
      activation=tf.nn.relu)
    
    # Convolutional Layer #1
    conv3 = tf.layers.conv2d(
      inputs=conv2,
      filters=5,
      strides=[1,1],
      kernel_size=[1, 2],
      padding="same",
      activation=tf.nn.relu)
    
    # Convolutional Layer #1
    conv4 = tf.layers.conv2d(
      inputs=conv3,
      filters=5,
      strides=[1,1],
      kernel_size=[1, 2],
      padding="same",
      activation=tf.nn.relu)
    
    # Convolutional Layer #1
    conv5 = tf.layers.conv2d(
      inputs=conv4,
      filters=5,
      strides=[1,1],
      kernel_size=[1, 2],
      padding="same",
      activation=tf.nn.relu)

  #pool layer #1
    pool = tf.layers.max_pooling2d(inputs=conv5, pool_size=[1, 2], strides=2)
    print(pool)
  
  # Dense Layer
    pool_flat = tf.reshape(pool, [-1, 9 *5])
    dense = tf.layers.dense(inputs=pool_flat, units=20, activation=tf.nn.relu)
  
  # Logits Layer
    logits = tf.layers.dense(inputs=dense, units=2)

    predictions = { \
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1), \
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")\
  }

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

  # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

  # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.0001)
        train_op = optimizer.minimize(loss=loss,global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

  # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {"accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])}
  
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
# Create the Estimator
mnist_classifier = tf.estimator.Estimator(model_fn=cnn_model_fn, model_dir="./tf_scores/")

  # Set up logging for predictions
tensors_to_log = {"probabilities": "softmax_tensor"}
logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=50)

  # Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=1,
    num_epochs=None,
    shuffle=True)
  
mnist_classifier.train(input_fn=train_input_fn,steps=5000,hooks=[logging_hook])

  # Evaluate the model and print results
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=1,
    shuffle=False)
  
eval_results = mnist_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './tf_scores/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000287B730A160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# Tensor("max_pooling2d/MaxPool:0", shape=(1, 1, 9, 5), dtype=float32)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./tf_scores/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5001 into ./tf_scores/model.ckpt.
# INFO:tensorflow:probabilities = [[0.38856345 0.6114366 ]]
# INFO:tensorflow:loss = 0.9452988, step = 5001
# INFO:tensorflow:probabilities = [[0.21016471 0.7898353 ]] (0.348 sec)
# INFO:tensorflow:global_step/sec: 175.662
# INFO:tensorflow:probabilities = [[0.33158043 0.66841954]] (0.206 sec)
# INFO:tensorflow:loss = 0.4028392, step = 5101 (0.554 sec)
# INFO:tensorflow:probabilities = [[0.44363397 0.556366  ]] (0.201 sec)
# INFO:tensorflow:global_step/sec: 231.271
# INFO:tensorflow:probabilities = [[0.34359738 0.6564025 ]] (0.232 sec)
# INFO:tensorflow:loss = 0.42098096, step = 5201 (0.432 sec)
# INFO:tensorflow:probabilities = [[0.23617843 0.7638216 ]] (0.332 sec)
# INFO:tensorflow:global_step/sec: 193.794
# INFO:tensorflow:probabilities = [[0.25972006 0.7402799 ]] (0.184 sec)
# INFO:tensorflow:loss = 0.30072686, step = 5301 (0.516 sec)
# INFO:tensorflow:probabilities = [[0.30900684 0.6909932 ]] (0.201 sec)
# INFO:tensorflow:global_step/sec: 249.331
# INFO:tensorflow:probabilities = [[0.15615731 0.8438427 ]] (0.216 sec)
# INFO:tensorflow:loss = 0.16978921, step = 5401 (0.417 sec)
# INFO:tensorflow:probabilities = [[0.36684158 0.6331584 ]] (0.269 sec)
# INFO:tensorflow:global_step/sec: 153.564
# INFO:tensorflow:probabilities = [[0.32319552 0.6768045 ]] (0.369 sec)
# INFO:tensorflow:loss = 0.39037284, step = 5501 (0.638 sec)
# INFO:tensorflow:probabilities = [[0.22519657 0.77480346]] (0.200 sec)
# INFO:tensorflow:global_step/sec: 230.198
# INFO:tensorflow:probabilities = [[0.28344193 0.7165581 ]] (0.232 sec)
# INFO:tensorflow:loss = 1.260748, step = 5601 (0.432 sec)
# INFO:tensorflow:probabilities = [[0.4240899  0.57591003]] (0.200 sec)
# INFO:tensorflow:global_step/sec: 240.762
# INFO:tensorflow:probabilities = [[0.27023104 0.72976893]] (0.216 sec)
# INFO:tensorflow:loss = 0.3150273, step = 5701 (0.415 sec)
# INFO:tensorflow:probabilities = [[0.20951636 0.79048365]] (0.201 sec)
# INFO:tensorflow:global_step/sec: 270.685
# INFO:tensorflow:probabilities = [[0.2875649 0.7124351]] (0.169 sec)
# INFO:tensorflow:loss = 0.33906642, step = 5801 (0.369 sec)
# INFO:tensorflow:probabilities = [[0.37965125 0.62034875]] (0.185 sec)
# INFO:tensorflow:global_step/sec: 275.662
# INFO:tensorflow:probabilities = [[0.46783823 0.5321617 ]] (0.178 sec)
# INFO:tensorflow:loss = 0.75963265, step = 5901 (0.363 sec)
# INFO:tensorflow:probabilities = [[0.42683142 0.57316864]] (0.200 sec)
# INFO:tensorflow:global_step/sec: 212.789
# INFO:tensorflow:probabilities = [[0.28015402 0.719846  ]] (0.269 sec)
# INFO:tensorflow:loss = 0.32871798, step = 6001 (0.470 sec)
# INFO:tensorflow:probabilities = [[0.23888156 0.7611184 ]] (0.216 sec)
# INFO:tensorflow:global_step/sec: 249.502
# INFO:tensorflow:probabilities = [[0.14010227 0.8598977 ]] (0.201 sec)
# INFO:tensorflow:loss = 0.15094188, step = 6101 (0.416 sec)
# INFO:tensorflow:probabilities = [[0.16554831 0.8344516 ]] (0.169 sec)
# INFO:tensorflow:global_step/sec: 222.928
# INFO:tensorflow:probabilities = [[0.2159275  0.78407246]] (0.268 sec)
# INFO:tensorflow:loss = 0.24325381, step = 6201 (0.437 sec)
# INFO:tensorflow:probabilities = [[0.35940948 0.64059055]] (0.179 sec)
# INFO:tensorflow:global_step/sec: 272.145
# INFO:tensorflow:probabilities = [[0.1955419  0.80445814]] (0.184 sec)
# INFO:tensorflow:loss = 0.21758634, step = 6301 (0.363 sec)
# INFO:tensorflow:probabilities = [[0.24134491 0.7586551 ]] (0.169 sec)
# INFO:tensorflow:global_step/sec: 240.717
# INFO:tensorflow:probabilities = [[0.3148161  0.68518394]] (0.246 sec)
# INFO:tensorflow:loss = 0.378068, step = 6401 (0.415 sec)
# INFO:tensorflow:probabilities = [[0.18401936 0.8159806 ]] (0.238 sec)
# INFO:tensorflow:global_step/sec: 213.025
# INFO:tensorflow:probabilities = [[0.319009 0.680991]] (0.232 sec)
# INFO:tensorflow:loss = 0.38420618, step = 6501 (0.469 sec)
# INFO:tensorflow:probabilities = [[0.333129   0.66687095]] (0.185 sec)
# INFO:tensorflow:global_step/sec: 259.82
# INFO:tensorflow:probabilities = [[0.30594367 0.69405633]] (0.200 sec)
# INFO:tensorflow:loss = 1.1843543, step = 6601 (0.385 sec)
# INFO:tensorflow:probabilities = [[0.32741138 0.67258865]] (0.200 sec)
# INFO:tensorflow:global_step/sec: 271.108
# INFO:tensorflow:probabilities = [[0.18441868 0.8155813 ]] (0.168 sec)
# INFO:tensorflow:loss = 0.20385413, step = 6701 (0.369 sec)
# INFO:tensorflow:probabilities = [[0.23587069 0.7641293 ]] (0.232 sec)
# INFO:tensorflow:global_step/sec: 231.61
# INFO:tensorflow:probabilities = [[0.36075637 0.63924366]] (0.200 sec)
# INFO:tensorflow:loss = 0.4474696, step = 6801 (0.432 sec)
# INFO:tensorflow:probabilities = [[0.17406422 0.82593584]] (0.269 sec)
# INFO:tensorflow:global_step/sec: 200.031
# INFO:tensorflow:probabilities = [[0.3412774  0.65872264]] (0.231 sec)
# INFO:tensorflow:loss = 0.41745272, step = 6901 (0.500 sec)
# INFO:tensorflow:probabilities = [[0.42016357 0.5798365 ]] (0.263 sec)
# INFO:tensorflow:global_step/sec: 199.838
# INFO:tensorflow:probabilities = [[0.23465933 0.7653406 ]] (0.237 sec)
# INFO:tensorflow:loss = 0.26743427, step = 7001 (0.500 sec)
# INFO:tensorflow:probabilities = [[0.37465584 0.62534416]] (0.201 sec)
# INFO:tensorflow:global_step/sec: 249.573
# INFO:tensorflow:probabilities = [[0.15082757 0.8491725 ]] (0.200 sec)
# INFO:tensorflow:loss = 1.891618, step = 7101 (0.401 sec)
# INFO:tensorflow:probabilities = [[0.38742742 0.61257255]] (0.168 sec)
# INFO:tensorflow:global_step/sec: 301.526
# INFO:tensorflow:probabilities = [[0.40336844 0.5966315 ]] (0.179 sec)
# INFO:tensorflow:loss = 0.51645553, step = 7201 (0.347 sec)
# INFO:tensorflow:probabilities = [[0.3209702 0.6790298]] (0.169 sec)
# INFO:tensorflow:global_step/sec: 282.666
# INFO:tensorflow:probabilities = [[0.31461522 0.68538475]] (0.169 sec)
# INFO:tensorflow:loss = 0.37777486, step = 7301 (0.338 sec)
# INFO:tensorflow:probabilities = [[0.22344203 0.7765579 ]] (0.162 sec)
# INFO:tensorflow:global_step/sec: 249.429
# INFO:tensorflow:probabilities = [[0.19608895 0.8039111 ]] (0.239 sec)
# INFO:tensorflow:loss = 0.2182666, step = 7401 (0.401 sec)
# INFO:tensorflow:probabilities = [[0.2413101 0.7586899]] (0.263 sec)
# INFO:tensorflow:global_step/sec: 215.846
# INFO:tensorflow:probabilities = [[0.33394775 0.6660522 ]] (0.200 sec)
# INFO:tensorflow:loss = 1.0967708, step = 7501 (0.463 sec)
# INFO:tensorflow:probabilities = [[0.26348487 0.73651516]] (0.185 sec)
# INFO:tensorflow:global_step/sec: 282.828
# INFO:tensorflow:probabilities = [[0.1387419 0.8612581]] (0.185 sec)
# INFO:tensorflow:loss = 0.14936098, step = 7601 (0.369 sec)
# INFO:tensorflow:probabilities = [[0.2477885  0.75221145]] (0.168 sec)
# INFO:tensorflow:global_step/sec: 275.042
# INFO:tensorflow:probabilities = [[0.25158158 0.7484184 ]] (0.185 sec)
# INFO:tensorflow:loss = 0.2897931, step = 7701 (0.353 sec)
# INFO:tensorflow:probabilities = [[0.2669207 0.7330793]] (0.231 sec)
# INFO:tensorflow:global_step/sec: 237.459
# INFO:tensorflow:probabilities = [[0.21088561 0.7891144 ]] (0.185 sec)
# INFO:tensorflow:loss = 0.23684397, step = 7801 (0.416 sec)
# INFO:tensorflow:probabilities = [[0.17952403 0.8204759 ]] (0.184 sec)
# INFO:tensorflow:global_step/sec: 260.117
# INFO:tensorflow:probabilities = [[0.20985658 0.79014343]] (0.201 sec)
# INFO:tensorflow:loss = 1.561331, step = 7901 (0.384 sec)
# INFO:tensorflow:probabilities = [[0.29675433 0.70324564]] (0.278 sec)
# INFO:tensorflow:global_step/sec: 194.02
# INFO:tensorflow:probabilities = [[0.2706232 0.7293768]] (0.238 sec)
# INFO:tensorflow:loss = 0.31556478, step = 8001 (0.531 sec)
# INFO:tensorflow:probabilities = [[0.19831005 0.80169   ]] (0.263 sec)
# INFO:tensorflow:global_step/sec: 199.793
# INFO:tensorflow:probabilities = [[0.25949374 0.7405063 ]] (0.237 sec)
# INFO:tensorflow:loss = 0.30042112, step = 8101 (0.485 sec)
# INFO:tensorflow:probabilities = [[0.15223344 0.8477666 ]] (0.300 sec)
# INFO:tensorflow:global_step/sec: 182.706
# INFO:tensorflow:probabilities = [[0.36881202 0.631188  ]] (0.247 sec)
# INFO:tensorflow:loss = 0.9974681, step = 8201 (0.547 sec)
# INFO:tensorflow:probabilities = [[0.33191195 0.6680881 ]] (0.300 sec)
# INFO:tensorflow:global_step/sec: 149.575
# INFO:tensorflow:probabilities = [[0.3159289 0.6840711]] (0.368 sec)
# INFO:tensorflow:loss = 1.1522381, step = 8301 (0.669 sec)
# INFO:tensorflow:probabilities = [[0.2261939  0.77380615]] (0.332 sec)
# INFO:tensorflow:global_step/sec: 158.229
# INFO:tensorflow:probabilities = [[0.38868976 0.61131024]] (0.300 sec)
# INFO:tensorflow:loss = 0.49215063, step = 8401 (0.648 sec)
# INFO:tensorflow:probabilities = [[0.4026071  0.59739286]] (0.253 sec)
# INFO:tensorflow:global_step/sec: 228.662
# INFO:tensorflow:probabilities = [[0.19987108 0.8001289 ]] (0.184 sec)
# INFO:tensorflow:loss = 0.22298247, step = 8501 (0.422 sec)
# INFO:tensorflow:probabilities = [[0.3015107 0.6984893]] (0.179 sec)
# INFO:tensorflow:global_step/sec: 263.953
# INFO:tensorflow:probabilities = [[0.41948202 0.580518  ]] (0.200 sec)
# INFO:tensorflow:loss = 0.86873466, step = 8601 (0.379 sec)
# INFO:tensorflow:probabilities = [[0.57725126 0.4227487 ]] (0.238 sec)
# INFO:tensorflow:global_step/sec: 199.628
# INFO:tensorflow:probabilities = [[0.3840104 0.6159896]] (0.263 sec)
# INFO:tensorflow:loss = 0.9570856, step = 8701 (0.501 sec)
# INFO:tensorflow:probabilities = [[0.31837806 0.6816219 ]] (0.221 sec)
# INFO:tensorflow:global_step/sec: 175.565
# INFO:tensorflow:probabilities = [[0.19501743 0.80498254]] (0.348 sec)
# INFO:tensorflow:loss = 1.6346663, step = 8801 (0.570 sec)
# INFO:tensorflow:probabilities = [[0.17597559 0.8240244 ]] (0.253 sec)
# INFO:tensorflow:global_step/sec: 220.556
# INFO:tensorflow:probabilities = [[0.43390778 0.5660922 ]] (0.201 sec)
# INFO:tensorflow:loss = 0.8349232, step = 8901 (0.453 sec)
# INFO:tensorflow:probabilities = [[0.38677666 0.61322343]] (0.347 sec)
# INFO:tensorflow:global_step/sec: 187.94
# INFO:tensorflow:probabilities = [[0.23386401 0.76613605]] (0.201 sec)
# INFO:tensorflow:loss = 0.26639554, step = 9001 (0.548 sec)
# INFO:tensorflow:probabilities = [[0.19831666 0.80168337]] (0.253 sec)
# INFO:tensorflow:global_step/sec: 215.669
# INFO:tensorflow:probabilities = [[0.3118203  0.68817973]] (0.197 sec)
# INFO:tensorflow:loss = 1.1653283, step = 9101 (0.451 sec)
# INFO:tensorflow:probabilities = [[0.35540676 0.6445933 ]] (0.203 sec)
# INFO:tensorflow:global_step/sec: 206.813
# INFO:tensorflow:probabilities = [[0.34125414 0.6587458 ]] (0.294 sec)
# INFO:tensorflow:loss = 1.0751278, step = 9201 (0.497 sec)
# INFO:tensorflow:probabilities = [[0.3750405 0.6249595]] (0.222 sec)
# INFO:tensorflow:global_step/sec: 228.564
# INFO:tensorflow:probabilities = [[0.2665783 0.7334217]] (0.200 sec)
# INFO:tensorflow:loss = 0.31003445, step = 9301 (0.421 sec)
# INFO:tensorflow:probabilities = [[0.2689976 0.7310024]] (0.201 sec)
# INFO:tensorflow:global_step/sec: 231.455
# INFO:tensorflow:probabilities = [[0.39259198 0.60740805]] (0.231 sec)
# INFO:tensorflow:loss = 0.9349845, step = 9401 (0.432 sec)
# INFO:tensorflow:probabilities = [[0.17067462 0.8293254 ]] (0.169 sec)
# INFO:tensorflow:global_step/sec: 282.983
# INFO:tensorflow:probabilities = [[0.4045788 0.5954212]] (0.184 sec)
# INFO:tensorflow:loss = 0.9049088, step = 9501 (0.353 sec)
# INFO:tensorflow:probabilities = [[0.28117907 0.7188209 ]] (0.248 sec)
# INFO:tensorflow:global_step/sec: 223.146
# INFO:tensorflow:probabilities = [[0.19078171 0.80921835]] (0.216 sec)
# INFO:tensorflow:loss = 0.21168654, step = 9601 (0.464 sec)
# INFO:tensorflow:probabilities = [[0.15720752 0.8427925 ]] (0.216 sec)
# INFO:tensorflow:global_step/sec: 231.778
# INFO:tensorflow:probabilities = [[0.48227775 0.5177222 ]] (0.200 sec)
# INFO:tensorflow:loss = 0.65831643, step = 9701 (0.416 sec)
# INFO:tensorflow:probabilities = [[0.3039957 0.6960043]] (0.253 sec)
# INFO:tensorflow:global_step/sec: 175.821
# INFO:tensorflow:probabilities = [[0.27545956 0.7245404 ]] (0.316 sec)
# INFO:tensorflow:loss = 1.2893144, step = 9801 (0.569 sec)
# INFO:tensorflow:probabilities = [[0.27458447 0.7254155 ]] (0.216 sec)
# INFO:tensorflow:global_step/sec: 220.608
# INFO:tensorflow:probabilities = [[0.2878144  0.71218556]] (0.253 sec)
# INFO:tensorflow:loss = 1.2454394, step = 9901 (0.469 sec)
# INFO:tensorflow:probabilities = [[0.27015176 0.72984827]] (0.163 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./tf_scores/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.454632.
# INFO:tensorflow:Calling model_fn.
# Tensor("max_pooling2d/MaxPool:0", shape=(?, 1, 9, 5), dtype=float32)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-28-05:43:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./tf_scores/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-28-05:43:41
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.70583457, global_step = 10000, loss = 0.59484965
# {'accuracy': 0.70583457, 'loss': 0.59484965, 'global_step': 10000}
